# %%
# %%writefile julia_set.cu
# /*
# Interesting Coordinates:
#
# (0.3, 0.2) - Spiraling tendrils
# (-0.4, 0.6) - Intricate branches
# (0.285, 0.01) - Deep self-similar patterns (current default)
# (-0.8, 0.156) - Feathery structures
# 0.11230583918508258 -0.17749724081559552
# */
# #include <stdio.h>
# #include <stdlib.h>
# #include <string.h>
# #include <stdbool.h>
# #include <cuda_runtime.h>
# #include <math.h>
#
# #define WIDTH 1920
# #define HEIGHT 1080
# #define MAX_ITER 256
# #define PI 3.14159265358979323846
#
# // Color palette for beautiful visualization
# struct Color {
#     unsigned char r, g, b;
# };
#
# // Generate smooth color gradient with more vibrant colors
# __host__ __device__ Color getColor(int iter, int max_iter) {
#     if (iter == max_iter) {
#         return {0, 0, 0};  // Black for points in the set
#     }
#
#     // Smooth coloring with vibrant palette using sine waves
#     float t = (float)iter / max_iter;
#
#     Color c;
#     // Vibrant psychedelic colors
#     c.r = (unsigned char)(255 * (0.5 + 0.5 * sin(6.28318 * t + 0.0)));
#     c.g = (unsigned char)(255 * (0.5 + 0.5 * sin(6.28318 * t + 2.094)));
#     c.b = (unsigned char)(255 * (0.5 + 0.5 * sin(6.28318 * t + 4.189)));
#
#     return c;
# }
#
# // CPU implementation - sequential Julia set computation
# void juliaSetCPU(Color *image, int width, int height,
#                  double centerX, double centerY, double zoom,
#                  double cReal, double cImag, int maxIter) {
#     double scale = 4.0 / (zoom * width);
#
#     for (int py = 0; py < height; py++) {
#         for (int px = 0; px < width; px++) {
#             // Map pixel to complex plane (this is our starting z)
#             double zReal = centerX + (px - width / 2.0) * scale;
#             double zImag = centerY + (py - height / 2.0) * scale;
#
#             int iter = 0;
#
#             // Iterate: z = z^2 + c (c is constant, z varies by pixel)
#             while (zReal*zReal + zImag*zImag <= 4.0 && iter < maxIter) {
#                 double zRealTemp = zReal*zReal - zImag*zImag + cReal;
#                 zImag = 2*zReal*zImag + cImag;
#                 zReal = zRealTemp;
#                 iter++;
#             }
#
#             image[py * width + px] = getColor(iter, maxIter);
#         }
#     }
# }
#
# // GPU kernel - parallel Julia set computation
# __global__ void juliaSetGPU(Color *image, int width, int height,
#                              double centerX, double centerY, double zoom,
#                              double cReal, double cImag, int maxIter) {
#     int px = blockIdx.x * blockDim.x + threadIdx.x;
#     int py = blockIdx.y * blockDim.y + threadIdx.y;
#
#     if (px >= width || py >= height) return;
#
#     double scale = 4.0 / (zoom * width);
#
#     // Map pixel to complex plane (this is our starting z)
#     double zReal = centerX + (px - width / 2.0) * scale;
#     double zImag = centerY + (py - height / 2.0) * scale;
#
#     int iter = 0;
#
#     // Iterate: z = z^2 + c (c is constant, z varies by pixel)
#     while (zReal*zReal + zImag*zImag <= 4.0 && iter < maxIter) {
#         double zRealTemp = zReal*zReal - zImag*zImag + cReal;
#         zImag = 2*zReal*zImag + cImag;
#         zReal = zRealTemp;
#         iter++;
#     }
#
#     image[py * width + px] = getColor(iter, maxIter);
# }
#
# // Save image as PPM file
# void savePPM(const char *filename, Color *image, int width, int height) {
#     FILE *fp = fopen(filename, "wb");
#     if (fp == NULL) {
#         printf("Error: Could not open file %s\n", filename);
#         return;
#     }
#     fprintf(fp, "P6\n%d %d\n255\n", width, height);
#     fwrite(image, sizeof(Color), width * height, fp);
#     fclose(fp);
#     printf("Saved: %s\n", filename);
# }
#
# int main(int argc, char *argv[]) {
#     // Default parameters
#     int cpuStartFrame = 1;
#     int cpuEndFrame = 15;
#     int gpuStartFrame = 1;
#     int gpuEndFrame = 15;
#     int cycleLength = 100;
#     double centerX = 0.285;
#     double centerY = 0.01;
#     double zoomStart = 1.0;
#     double zoomEnd = 500.0;
#     double animationStopPercent = 0.7;  // Stop c-parameter animation at 70% zoom
#     bool renderCPU = true;
#     bool renderGPU = true;
#
#     // Parse command line arguments
#     for (int i = 1; i < argc; i++) {
#         if (strcmp(argv[i], "--cpu-start") == 0 && i + 1 < argc) {
#             cpuStartFrame = atoi(argv[++i]);
#         } else if (strcmp(argv[i], "--cpu-end") == 0 && i + 1 < argc) {
#             cpuEndFrame = atoi(argv[++i]);
#         } else if (strcmp(argv[i], "--gpu-start") == 0 && i + 1 < argc) {
#             gpuStartFrame = atoi(argv[++i]);
#         } else if (strcmp(argv[i], "--gpu-end") == 0 && i + 1 < argc) {
#             gpuEndFrame = atoi(argv[++i]);
#         } else if (strcmp(argv[i], "--start") == 0 && i + 1 < argc) {
#             cpuStartFrame = gpuStartFrame = atoi(argv[++i]);
#         } else if (strcmp(argv[i], "--end") == 0 && i + 1 < argc) {
#             cpuEndFrame = gpuEndFrame = atoi(argv[++i]);
#         } else if (strcmp(argv[i], "--cpu-only") == 0) {
#             renderGPU = false;
#         } else if (strcmp(argv[i], "--gpu-only") == 0) {
#             renderCPU = false;
#         } else if (strcmp(argv[i], "--cycle-length") == 0 && i + 1 < argc) {
#             cycleLength = atoi(argv[++i]);
#         } else if (strcmp(argv[i], "--zoom") == 0 && i + 1 < argc) {
#             zoomEnd = atof(argv[++i]);
#         } else if (strcmp(argv[i], "--centerX") == 0 && i + 1 < argc) {
#             centerX = atof(argv[++i]);
#         } else if (strcmp(argv[i], "--centerY") == 0 && i + 1 < argc) {
#             centerY = atof(argv[++i]);
#         } else if (strcmp(argv[i], "--animation-stop") == 0 && i + 1 < argc) {
#             animationStopPercent = atof(argv[++i]);
#             if (animationStopPercent < 0.0) animationStopPercent = 0.0;
#             if (animationStopPercent > 1.0) animationStopPercent = 1.0;
#         } else if (strcmp(argv[i], "--help") == 0 || strcmp(argv[i], "-h") == 0) {
#             printf("Usage: %s [OPTIONS]\n\n", argv[0]);
#             printf("Frame Range Options:\n");
#             printf("  --start N           Set both CPU and GPU start frame (default: 1)\n");
#             printf("  --end N             Set both CPU and GPU end frame (default: 15)\n");
#             printf("  --cpu-start N       CPU start frame (default: 1)\n");
#             printf("  --cpu-end N         CPU end frame (default: 15)\n");
#             printf("  --gpu-start N       GPU start frame (default: 1)\n");
#             printf("  --gpu-end N         GPU end frame (default: 15)\n");
#             printf("  --cpu-only          Skip GPU rendering\n");
#             printf("  --gpu-only          Skip CPU rendering\n\n");
#             printf("Animation Options:\n");
#             printf("  --cycle-length N    Animation cycle length in frames (default: 100)\n");
#             printf("  --zoom N            Maximum zoom level (default: 500.0)\n");
#             printf("  --centerX N         Zoom center X coordinate (default: 0.285)\n");
#             printf("  --centerY N         Zoom center Y coordinate (default: 0.01)\n");
#             printf("  --animation-stop N  Stop c-parameter animation at N percent (0.0-1.0, default: 0.7)\n");
#             printf("                      Use 0.0 to animate throughout, 1.0 for no animation\n\n");
#             printf("Other:\n");
#             printf("  --help, -h          Show this help message\n\n");
#             printf("Examples:\n");
#             printf("  %s --start 1 --end 100\n", argv[0]);
#             printf("  %s --cpu-start 1 --cpu-end 10 --gpu-start 1 --gpu-end 100\n", argv[0]);
#             printf("  %s --gpu-only --start 1 --end 200\n", argv[0]);
#             printf("  %s --cpu-end 5 --gpu-end 50 --zoom 1000\n", argv[0]);
#             printf("  %s --animation-stop 0.3  (stop animation at 30%% zoom)\n", argv[0]);
#             printf("  %s --animation-stop 1.0  (no animation at all)\n\n", argv[0]);
#             printf("Interesting zoom locations:\n");
#             printf("  --centerX 0.3 --centerY 0.2      (Spiraling tendrils)\n");
#             printf("  --centerX -0.4 --centerY 0.6     (Intricate branches)\n");
#             printf("  --centerX 0.285 --centerY 0.01   (Deep self-similar patterns)\n");
#             printf("  --centerX -0.8 --centerY 0.156   (Feathery structures)\n");
#             return 0;
#         } else {
#             printf("Unknown option: %s\n", argv[i]);
#             printf("Use --help for usage information\n");
#             return 1;
#         }
#     }
#
#     // Validate parameters
#     if (cpuStartFrame < 1 || cpuEndFrame < cpuStartFrame) {
#         printf("Error: Invalid CPU frame range (start: %d, end: %d)\n", cpuStartFrame, cpuEndFrame);
#         return 1;
#     }
#
#     if (gpuStartFrame < 1 || gpuEndFrame < gpuStartFrame) {
#         printf("Error: Invalid GPU frame range (start: %d, end: %d)\n", gpuStartFrame, gpuEndFrame);
#         return 1;
#     }
#
#     if (cycleLength < 1) {
#         printf("Error: Cycle length must be >= 1\n");
#         return 1;
#     }
#
#     if (zoomEnd <= zoomStart) {
#         printf("Error: Zoom end (%.1f) must be greater than zoom start (%.1f)\n", zoomEnd, zoomStart);
#         return 1;
#     }
#
#     int cpuNumFrames = cpuEndFrame - cpuStartFrame + 1;
#     int gpuNumFrames = gpuEndFrame - gpuStartFrame + 1;
#
#     printf("===========================================\n");
#     printf("JULIA SET: CPU vs GPU Performance\n");
#     printf("Resolution: %dx%d (%d megapixels)\n", WIDTH, HEIGHT, (WIDTH*HEIGHT)/1000000);
#     printf("===========================================\n\n");
#
#     // Set output directory (works for both local and Google Drive)
#     const char *outputDir = "./";
#
#     // Check if running in Google Colab with mounted Drive
#     FILE *testDrive = fopen("/content/drive/MyDrive/test", "w");
#     if (testDrive != NULL) {
#         fclose(testDrive);
#         remove("/content/drive/MyDrive/test");
#         outputDir = "/content/drive/MyDrive/julia_set/";
#         printf("Google Drive detected! Saving to: %s\n", outputDir);
#
#         // Create output directory
#         system("mkdir -p /content/drive/MyDrive/julia_set");
#     } else {
#         printf("Saving to local directory: %s\n", outputDir);
#     }
#     printf("\n");
#
#     size_t imageSize = WIDTH * HEIGHT * sizeof(Color);
#
#     // Allocate host memory
#     Color *h_image_cpu = (Color*)malloc(imageSize);
#     Color *h_image_gpu = (Color*)malloc(imageSize);
#
#     printf("Rendering animated Julia set sequence...\n");
#     printf("Parameters:\n");
#     if (renderCPU) {
#         printf("  CPU frames: %d to %d (%d total frames)\n", cpuStartFrame, cpuEndFrame, cpuNumFrames);
#     } else {
#         printf("  CPU rendering: DISABLED\n");
#     }
#     if (renderGPU) {
#         printf("  GPU frames: %d to %d (%d total frames)\n", gpuStartFrame, gpuEndFrame, gpuNumFrames);
#     } else {
#         printf("  GPU rendering: DISABLED\n");
#     }
#     printf("  Cycle length: %d frames\n", cycleLength);
#     printf("  Zoom center: (%.3f, %.3f)\n", centerX, centerY);
#     printf("  Zoom range: %.1fx to %.1fx\n", zoomStart, zoomEnd);
#     printf("  Animation stops at: %.0f%% of zoom\n\n", animationStopPercent * 100);
#
#     // ============================================
#     // CPU RENDERING
#     // ============================================
#     clock_t totalCPUTime = 0;
#     double avgCPUTime = 0;
#
#     if (renderCPU) {
#         printf("CPU Rendering:\n");
#         printf("------------------------------------------\n");
#
#         // Open CSV file for CPU values
#         char csvFilename[200];
#         sprintf(csvFilename, "%scpu_values.csv", outputDir);
#         printf("Creating CSV: %s\n", csvFilename);
#         FILE *csvFile = fopen(csvFilename, "w");
#         if (csvFile == NULL) {
#             printf("ERROR: Could not create CPU CSV file!\n");
#         } else {
#             fprintf(csvFile, "frame,centerX,centerY,zoom\n");
#         }
#
#         for (int i = 0; i < cpuNumFrames; i++) {
#             int frameNum = cpuStartFrame + i;
#
#             // Animate the c parameter for morphing effect
#             double angle = 2 * PI * frameNum / (double)cycleLength;
#
#             // Stop animation at specified percent through the zoom for stability
#             double zoomFactor = (frameNum - 1.0) / cycleLength;
#             double dampening;
#             if (zoomFactor < animationStopPercent) {
#                 // Normal animation
#                 dampening = 1.0;
#             } else {
#                 // Freeze animation at deep zoom
#                 dampening = 0.0;
#                 // Lock angle to what it was at stop point
#                 angle = 2 * PI * (animationStopPercent * cycleLength) / (double)cycleLength;
#             }
#
#             double cReal = -0.7 + 0.2 * cos(angle) * dampening;
#             double cImag = 0.27015 + 0.1 * sin(angle) * dampening;
#
#             // Calculate zoom
#             double t = (double)(frameNum - 1) / (double)cycleLength;
#             double zoom = zoomStart * pow(zoomEnd / zoomStart, t);
#
#             // Scale iterations with zoom for better detail at high magnification
#             int iterations = (int)(MAX_ITER * (1.0 + log10(zoom)));
#             if (iterations > MAX_ITER * 4) iterations = MAX_ITER * 4;  // Cap at 4x
#
#             // Write to CSV with high precision
#             if (csvFile != NULL) {
#                 fprintf(csvFile, "%d,%.15f,%.15f,%.6f\n", frameNum, centerX, centerY, zoom);
#             }
#
#             clock_t start = clock();
#             juliaSetCPU(h_image_cpu, WIDTH, HEIGHT, centerX, centerY, zoom, cReal, cImag, iterations);
#             clock_t end = clock();
#
#             double frameTime = ((double)(end - start)) / CLOCKS_PER_SEC;
#             totalCPUTime += (end - start);
#
#             printf("Frame %d (zoom: %.1fx): %.3f seconds\n", frameNum, zoom, frameTime);
#
#             // Save frame
#             char filename[200];
#             sprintf(filename, "%sjulia_cpu_%04d.ppm", outputDir, frameNum);
#             savePPM(filename, h_image_cpu, WIDTH, HEIGHT);
#         }
#
#         avgCPUTime = ((double)totalCPUTime / CLOCKS_PER_SEC) / cpuNumFrames;
#         float cpuFPS = 1.0 / avgCPUTime;
#         printf("\nAverage CPU time: %.3f seconds\n", avgCPUTime);
#         printf("CPU FPS: %.2f\n\n", cpuFPS);
#
#         // Write FPS and close CSV
#         if (csvFile != NULL) {
#             fprintf(csvFile, "fps,%.2f,0,0\n", cpuFPS);
#             fclose(csvFile);
#             printf("Saved: %scpu_values.csv\n\n", outputDir);
#         }
#     } else {
#         printf("CPU Rendering: SKIPPED\n\n");
#     }
#
#     // ============================================
#     // GPU RENDERING
#     // ============================================
#     float avgGPUTime = 0;
#
#     if (renderGPU) {
#         printf("GPU Rendering:\n");
#         printf("------------------------------------------\n");
#
#         // Allocate device memory
#         Color *d_image;
#         cudaMalloc(&d_image, imageSize);
#
#         // Setup kernel launch parameters
#         dim3 threadsPerBlock(16, 16);
#         dim3 blocksPerGrid((WIDTH + 15) / 16, (HEIGHT + 15) / 16);
#
#         printf("Grid: %dx%d blocks, Block: %dx%d threads\n",
#                blocksPerGrid.x, blocksPerGrid.y, threadsPerBlock.x, threadsPerBlock.y);
#         printf("Total GPU threads: %d\n\n",
#                blocksPerGrid.x * blocksPerGrid.y * threadsPerBlock.x * threadsPerBlock.y);
#
#         // Create CUDA events for timing
#         cudaEvent_t start, stop;
#         cudaEventCreate(&start);
#         cudaEventCreate(&stop);
#
#         // Open CSV file for GPU values
#         char csvFilename[200];
#         sprintf(csvFilename, "%sgpu_values.csv", outputDir);
#         printf("Creating CSV: %s\n", csvFilename);
#         FILE *csvFile = fopen(csvFilename, "w");
#         if (csvFile == NULL) {
#             printf("ERROR: Could not create GPU CSV file!\n");
#         } else {
#             fprintf(csvFile, "frame,centerX,centerY,zoom\n");
#         }
#
#         float totalGPUTime = 0.0f;
#
#         for (int i = 0; i < gpuNumFrames; i++) {
#             int frameNum = gpuStartFrame + i;
#
#             // Animate the c parameter for morphing effect
#             double angle = 2 * PI * frameNum / (double)cycleLength;
#
#             // Stop animation at specified percent through the zoom for stability
#             double zoomFactor = (frameNum - 1.0) / cycleLength;
#             double dampening;
#             if (zoomFactor < animationStopPercent) {
#                 // Normal animation
#                 dampening = 1.0;
#             } else {
#                 // Freeze animation at deep zoom
#                 dampening = 0.0;
#                 // Lock angle to what it was at stop point
#                 angle = 2 * PI * (animationStopPercent * cycleLength) / (double)cycleLength;
#             }
#
#             double cReal = -0.7 + 0.2 * cos(angle) * dampening;
#             double cImag = 0.27015 + 0.1 * sin(angle) * dampening;
#
#             // Calculate zoom
#             double t = (double)(frameNum - 1) / (double)cycleLength;
#             double zoom = zoomStart * pow(zoomEnd / zoomStart, t);
#
#             // Scale iterations with zoom for better detail at high magnification
#             int iterations = (int)(MAX_ITER * (1.0 + log10(zoom)));
#             if (iterations > MAX_ITER * 4) iterations = MAX_ITER * 4;  // Cap at 4x
#
#             // Write to CSV with high precision
#             if (csvFile != NULL) {
#                 fprintf(csvFile, "%d,%.15f,%.15f,%.6f\n", frameNum, centerX, centerY, zoom);
#             }
#
#             cudaEventRecord(start);
#
#             juliaSetGPU<<<blocksPerGrid, threadsPerBlock>>>(
#                 d_image, WIDTH, HEIGHT, centerX, centerY, zoom, cReal, cImag, iterations);
#
#             cudaEventRecord(stop);
#             cudaEventSynchronize(stop);
#
#             // Check for errors
#             cudaError_t err = cudaGetLastError();
#             if (err != cudaSuccess) {
#                 printf("Kernel error: %s\n", cudaGetErrorString(err));
#                 break;
#             }
#
#             float frameTime;
#             cudaEventElapsedTime(&frameTime, start, stop);
#             totalGPUTime += frameTime;
#
#             printf("Frame %d (zoom: %.1fx): %.3f seconds\n", frameNum, zoom, frameTime / 1000.0);
#
#             // Copy result and save frame
#             cudaMemcpy(h_image_gpu, d_image, imageSize, cudaMemcpyDeviceToHost);
#             char filename[200];
#             sprintf(filename, "%sjulia_gpu_%04d.ppm", outputDir, frameNum);
#             savePPM(filename, h_image_gpu, WIDTH, HEIGHT);
#         }
#
#         avgGPUTime = (totalGPUTime / 1000.0) / gpuNumFrames;
#         float gpuFPS = 1.0 / avgGPUTime;
#         printf("\nAverage GPU time: %.3f seconds\n", avgGPUTime);
#         printf("GPU FPS: %.2f\n\n", gpuFPS);
#
#         // Write FPS and close CSV
#         if (csvFile != NULL) {
#             fprintf(csvFile, "fps,%.2f,0,0\n", gpuFPS);
#             fclose(csvFile);
#             printf("Saved: %sgpu_values.csv\n\n", outputDir);
#         }
#
#         // Cleanup GPU resources
#         cudaFree(d_image);
#         cudaEventDestroy(start);
#         cudaEventDestroy(stop);
#     } else {
#         printf("GPU Rendering: SKIPPED\n\n");
#     }
#
#     // ============================================
#     // PERFORMANCE COMPARISON
#     // ============================================
#     printf("===========================================\n");
#     printf("PERFORMANCE SUMMARY\n");
#     printf("===========================================\n");
#
#     if (renderCPU && renderGPU) {
#         printf("Average CPU time: %.3f seconds (%.2f FPS)\n", avgCPUTime, 1.0 / avgCPUTime);
#         printf("Average GPU time: %.3f seconds (%.2f FPS)\n", avgGPUTime, 1.0 / avgGPUTime);
#         printf("Speedup:          %.2fx faster on GPU\n", avgCPUTime / avgGPUTime);
#     } else if (renderCPU) {
#         printf("Average CPU time: %.3f seconds (%.2f FPS)\n", avgCPUTime, 1.0 / avgCPUTime);
#         printf("GPU rendering was skipped\n");
#     } else if (renderGPU) {
#         printf("Average GPU time: %.3f seconds (%.2f FPS)\n", avgGPUTime, 1.0 / avgGPUTime);
#         printf("CPU rendering was skipped\n");
#     }
#     printf("===========================================\n\n");
#
#     if (renderGPU && avgGPUTime < 0.033) {
#         printf("✓ GPU can render at 30+ FPS!\n");
#         if (avgGPUTime < 0.016) {
#             printf("✓ GPU can render at 60+ FPS!\n");
#         }
#     }
#
#     printf("\nOutput files saved to: %s\n", outputDir);
#     if (renderCPU) {
#         printf("CPU: %d frames (%d to %d)\n", cpuNumFrames, cpuStartFrame, cpuEndFrame);
#     }
#     if (renderGPU) {
#         printf("GPU: %d frames (%d to %d)\n", gpuNumFrames, gpuStartFrame, gpuEndFrame);
#     }
#
#     // Cleanup
#     free(h_image_cpu);
#     free(h_image_gpu);
#
#     return 0;
# }
# Out:
# Overwriting julia_set.cu

# %%
from google.colab import drive
drive.mount('/content/drive')

# !nvcc -arch=sm_75 -o julia_set julia_set.cu
# !./julia_set --start 1 --cpu-end 30 --gpu-end 300 --cycle-length 300 --zoom 300 --animation-stop 0.4 --centerX  0.11230583918508258 --centerY -0.17749724081559552
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ===========================================
# JULIA SET: CPU vs GPU Performance
# Resolution: 1920x1080 (2 megapixels)
# ===========================================
#
# Google Drive detected! Saving to: /content/drive/MyDrive/julia_set/
#
# Rendering animated Julia set sequence...
# Parameters:
#   CPU frames: 1 to 30 (30 total frames)
#   GPU frames: 1 to 300 (300 total frames)
#   Cycle length: 300 frames
#   Zoom center: (0.112, -0.177)
#   Zoom range: 1.0x to 300.0x
#   Animation stops at: 40% of zoom
#
# CPU Rendering:
# ------------------------------------------
# Creating CSV: /content/drive/MyDrive/julia_set/cpu_values.csv
# Frame 1 (zoom: 1.0x): 1.344 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0001.ppm
# Frame 2 (zoom: 1.0x): 1.377 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0002.ppm
# Frame 3 (zoom: 1.0x): 1.299 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0003.ppm
# Frame 4 (zoom: 1.1x): 1.348 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0004.ppm
# Frame 5 (zoom: 1.1x): 1.402 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0005.ppm
# Frame 6 (zoom: 1.1x): 1.457 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0006.ppm
# Frame 7 (zoom: 1.1x): 1.527 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0007.ppm
# Frame 8 (zoom: 1.1x): 1.599 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0008.ppm
# Frame 9 (zoom: 1.2x): 1.723 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0009.ppm
# Frame 10 (zoom: 1.2x): 1.920 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0010.ppm
# Frame 11 (zoom: 1.2x): 1.810 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0011.ppm
# Frame 12 (zoom: 1.2x): 1.837 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0012.ppm
# Frame 13 (zoom: 1.3x): 1.923 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0013.ppm
# Frame 14 (zoom: 1.3x): 2.000 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0014.ppm
# Frame 15 (zoom: 1.3x): 2.078 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0015.ppm
# Frame 16 (zoom: 1.3x): 2.367 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0016.ppm
# Frame 17 (zoom: 1.4x): 2.327 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0017.ppm
# Frame 18 (zoom: 1.4x): 2.304 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0018.ppm
# Frame 19 (zoom: 1.4x): 2.392 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0019.ppm
# Frame 20 (zoom: 1.4x): 2.465 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0020.ppm
# Frame 21 (zoom: 1.5x): 2.653 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0021.ppm
# Frame 22 (zoom: 1.5x): 2.797 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0022.ppm
# Frame 23 (zoom: 1.5x): 2.695 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0023.ppm
# Frame 24 (zoom: 1.5x): 2.783 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0024.ppm
# Frame 25 (zoom: 1.6x): 2.850 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0025.ppm
# Frame 26 (zoom: 1.6x): 3.165 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0026.ppm
# Frame 27 (zoom: 1.6x): 3.059 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0027.ppm
# Frame 28 (zoom: 1.7x): 3.119 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0028.ppm
# Frame 29 (zoom: 1.7x): 3.200 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0029.ppm
# Frame 30 (zoom: 1.7x): 3.510 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_cpu_0030.ppm
#
# Average CPU time: 2.211 seconds
# CPU FPS: 0.45
#
# Saved: /content/drive/MyDrive/julia_set/cpu_values.csv
#
# GPU Rendering:
# ------------------------------------------
# Grid: 120x68 blocks, Block: 16x16 threads
# Total GPU threads: 2088960
#
# Creating CSV: /content/drive/MyDrive/julia_set/gpu_values.csv
# Frame 1 (zoom: 1.0x): 0.037 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0001.ppm
# Frame 2 (zoom: 1.0x): 0.038 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0002.ppm
# Frame 3 (zoom: 1.0x): 0.039 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0003.ppm
# Frame 4 (zoom: 1.1x): 0.030 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0004.ppm
# Frame 5 (zoom: 1.1x): 0.027 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0005.ppm
# Frame 6 (zoom: 1.1x): 0.028 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0006.ppm
# Frame 7 (zoom: 1.1x): 0.029 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0007.ppm
# Frame 8 (zoom: 1.1x): 0.030 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0008.ppm
# Frame 9 (zoom: 1.2x): 0.031 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0009.ppm
# Frame 10 (zoom: 1.2x): 0.032 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0010.ppm
# Frame 11 (zoom: 1.2x): 0.026 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0011.ppm
# Frame 12 (zoom: 1.2x): 0.021 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0012.ppm
# Frame 13 (zoom: 1.3x): 0.022 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0013.ppm
# Frame 14 (zoom: 1.3x): 0.022 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0014.ppm
# Frame 15 (zoom: 1.3x): 0.023 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0015.ppm
# Frame 16 (zoom: 1.3x): 0.024 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0016.ppm
# Frame 17 (zoom: 1.4x): 0.024 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0017.ppm
# Frame 18 (zoom: 1.4x): 0.025 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0018.ppm
# Frame 19 (zoom: 1.4x): 0.025 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0019.ppm
# Frame 20 (zoom: 1.4x): 0.026 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0020.ppm
# Frame 21 (zoom: 1.5x): 0.027 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0021.ppm
# Frame 22 (zoom: 1.5x): 0.028 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0022.ppm
# Frame 23 (zoom: 1.5x): 0.029 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0023.ppm
# Frame 24 (zoom: 1.5x): 0.030 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0024.ppm
# Frame 25 (zoom: 1.6x): 0.030 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0025.ppm
# Frame 26 (zoom: 1.6x): 0.031 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0026.ppm
# Frame 27 (zoom: 1.6x): 0.032 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0027.ppm
# Frame 28 (zoom: 1.7x): 0.033 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0028.ppm
# Frame 29 (zoom: 1.7x): 0.034 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0029.ppm
# Frame 30 (zoom: 1.7x): 0.034 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0030.ppm
# Frame 31 (zoom: 1.8x): 0.035 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0031.ppm
# Frame 32 (zoom: 1.8x): 0.036 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0032.ppm
# Frame 33 (zoom: 1.8x): 0.037 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0033.ppm
# Frame 34 (zoom: 1.9x): 0.037 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0034.ppm
# Frame 35 (zoom: 1.9x): 0.038 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0035.ppm
# Frame 36 (zoom: 1.9x): 0.039 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0036.ppm
# Frame 37 (zoom: 2.0x): 0.040 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0037.ppm
# Frame 38 (zoom: 2.0x): 0.041 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0038.ppm
# Frame 39 (zoom: 2.1x): 0.041 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0039.ppm
# Frame 40 (zoom: 2.1x): 0.042 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0040.ppm
# Frame 41 (zoom: 2.1x): 0.043 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0041.ppm
# Frame 42 (zoom: 2.2x): 0.043 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0042.ppm
# Frame 43 (zoom: 2.2x): 0.044 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0043.ppm
# Frame 44 (zoom: 2.3x): 0.044 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0044.ppm
# Frame 45 (zoom: 2.3x): 0.045 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0045.ppm
# Frame 46 (zoom: 2.4x): 0.046 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0046.ppm
# Frame 47 (zoom: 2.4x): 0.046 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0047.ppm
# Frame 48 (zoom: 2.4x): 0.046 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0048.ppm
# Frame 49 (zoom: 2.5x): 0.047 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0049.ppm
# Frame 50 (zoom: 2.5x): 0.047 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0050.ppm
# Frame 51 (zoom: 2.6x): 0.048 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0051.ppm
# Frame 52 (zoom: 2.6x): 0.048 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0052.ppm
# Frame 53 (zoom: 2.7x): 0.048 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0053.ppm
# Frame 54 (zoom: 2.7x): 0.049 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0054.ppm
# Frame 55 (zoom: 2.8x): 0.049 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0055.ppm
# Frame 56 (zoom: 2.8x): 0.049 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0056.ppm
# Frame 57 (zoom: 2.9x): 0.049 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0057.ppm
# Frame 58 (zoom: 3.0x): 0.050 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0058.ppm
# Frame 59 (zoom: 3.0x): 0.050 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0059.ppm
# Frame 60 (zoom: 3.1x): 0.050 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0060.ppm
# Frame 61 (zoom: 3.1x): 0.049 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0061.ppm
# Frame 62 (zoom: 3.2x): 0.047 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0062.ppm
# Frame 63 (zoom: 3.3x): 0.041 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0063.ppm
# Frame 64 (zoom: 3.3x): 0.032 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0064.ppm
# Frame 65 (zoom: 3.4x): 0.021 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0065.ppm
# Frame 66 (zoom: 3.4x): 0.015 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0066.ppm
# Frame 67 (zoom: 3.5x): 0.013 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0067.ppm
# Frame 68 (zoom: 3.6x): 0.012 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0068.ppm
# Frame 69 (zoom: 3.6x): 0.012 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0069.ppm
# Frame 70 (zoom: 3.7x): 0.011 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0070.ppm
# Frame 71 (zoom: 3.8x): 0.010 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0071.ppm
# Frame 72 (zoom: 3.9x): 0.010 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0072.ppm
# Frame 73 (zoom: 3.9x): 0.011 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0073.ppm
# Frame 74 (zoom: 4.0x): 0.011 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0074.ppm
# Frame 75 (zoom: 4.1x): 0.009 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0075.ppm
# Frame 76 (zoom: 4.2x): 0.008 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0076.ppm
# Frame 77 (zoom: 4.2x): 0.007 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0077.ppm
# Frame 78 (zoom: 4.3x): 0.007 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0078.ppm
# Frame 79 (zoom: 4.4x): 0.006 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0079.ppm
# Frame 80 (zoom: 4.5x): 0.006 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0080.ppm
# Frame 81 (zoom: 4.6x): 0.005 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0081.ppm
# Frame 82 (zoom: 4.7x): 0.005 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0082.ppm
# Frame 83 (zoom: 4.8x): 0.005 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0083.ppm
# Frame 84 (zoom: 4.8x): 0.004 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0084.ppm
# Frame 85 (zoom: 4.9x): 0.004 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0085.ppm
# Frame 86 (zoom: 5.0x): 0.004 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0086.ppm
# Frame 87 (zoom: 5.1x): 0.004 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0087.ppm
# Frame 88 (zoom: 5.2x): 0.004 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0088.ppm
# Frame 89 (zoom: 5.3x): 0.004 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0089.ppm
# Frame 90 (zoom: 5.4x): 0.004 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0090.ppm
# Frame 91 (zoom: 5.5x): 0.004 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0091.ppm
# Frame 92 (zoom: 5.6x): 0.004 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0092.ppm
# Frame 93 (zoom: 5.7x): 0.003 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0093.ppm
# Frame 94 (zoom: 5.9x): 0.003 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0094.ppm
# Frame 95 (zoom: 6.0x): 0.003 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0095.ppm
# Frame 96 (zoom: 6.1x): 0.003 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0096.ppm
# Frame 97 (zoom: 6.2x): 0.003 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0097.ppm
# Frame 98 (zoom: 6.3x): 0.003 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0098.ppm
# Frame 99 (zoom: 6.4x): 0.003 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0099.ppm
# Frame 100 (zoom: 6.6x): 0.003 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0100.ppm
# Frame 101 (zoom: 6.7x): 0.003 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0101.ppm
# Frame 102 (zoom: 6.8x): 0.003 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0102.ppm
# Frame 103 (zoom: 7.0x): 0.003 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0103.ppm
# Frame 104 (zoom: 7.1x): 0.003 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0104.ppm
# Frame 105 (zoom: 7.2x): 0.003 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0105.ppm
# Frame 106 (zoom: 7.4x): 0.003 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0106.ppm
# Frame 107 (zoom: 7.5x): 0.005 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0107.ppm
# Frame 108 (zoom: 7.6x): 0.005 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0108.ppm
# Frame 109 (zoom: 7.8x): 0.005 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0109.ppm
# Frame 110 (zoom: 7.9x): 0.005 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0110.ppm
# Frame 111 (zoom: 8.1x): 0.005 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0111.ppm
# Frame 112 (zoom: 8.3x): 0.005 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0112.ppm
# Frame 113 (zoom: 8.4x): 0.006 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0113.ppm
# Frame 114 (zoom: 8.6x): 0.006 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0114.ppm
# Frame 115 (zoom: 8.7x): 0.006 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0115.ppm
# Frame 116 (zoom: 8.9x): 0.006 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0116.ppm
# Frame 117 (zoom: 9.1x): 0.006 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0117.ppm
# Frame 118 (zoom: 9.2x): 0.006 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0118.ppm
# Frame 119 (zoom: 9.4x): 0.007 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0119.ppm
# Frame 120 (zoom: 9.6x): 0.007 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0120.ppm
# Frame 121 (zoom: 9.8x): 0.114 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0121.ppm
# Frame 122 (zoom: 10.0x): 0.072 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0122.ppm
# Frame 123 (zoom: 10.2x): 0.070 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0123.ppm
# Frame 124 (zoom: 10.4x): 0.057 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0124.ppm
# Frame 125 (zoom: 10.6x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0125.ppm
# Frame 126 (zoom: 10.8x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0126.ppm
# Frame 127 (zoom: 11.0x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0127.ppm
# Frame 128 (zoom: 11.2x): 0.057 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0128.ppm
# Frame 129 (zoom: 11.4x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0129.ppm
# Frame 130 (zoom: 11.6x): 0.057 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0130.ppm
# Frame 131 (zoom: 11.8x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0131.ppm
# Frame 132 (zoom: 12.1x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0132.ppm
# Frame 133 (zoom: 12.3x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0133.ppm
# Frame 134 (zoom: 12.5x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0134.ppm
# Frame 135 (zoom: 12.8x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0135.ppm
# Frame 136 (zoom: 13.0x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0136.ppm
# Frame 137 (zoom: 13.3x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0137.ppm
# Frame 138 (zoom: 13.5x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0138.ppm
# Frame 139 (zoom: 13.8x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0139.ppm
# Frame 140 (zoom: 14.1x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0140.ppm
# Frame 141 (zoom: 14.3x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0141.ppm
# Frame 142 (zoom: 14.6x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0142.ppm
# Frame 143 (zoom: 14.9x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0143.ppm
# Frame 144 (zoom: 15.2x): 0.055 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0144.ppm
# Frame 145 (zoom: 15.5x): 0.055 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0145.ppm
# Frame 146 (zoom: 15.7x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0146.ppm
# Frame 147 (zoom: 16.1x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0147.ppm
# Frame 148 (zoom: 16.4x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0148.ppm
# Frame 149 (zoom: 16.7x): 0.056 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0149.ppm
# Frame 150 (zoom: 17.0x): 0.057 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0150.ppm
# Frame 151 (zoom: 17.3x): 0.057 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0151.ppm
# Frame 152 (zoom: 17.7x): 0.057 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0152.ppm
# Frame 153 (zoom: 18.0x): 0.057 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0153.ppm
# Frame 154 (zoom: 18.3x): 0.058 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0154.ppm
# Frame 155 (zoom: 18.7x): 0.058 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0155.ppm
# Frame 156 (zoom: 19.0x): 0.059 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0156.ppm
# Frame 157 (zoom: 19.4x): 0.059 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0157.ppm
# Frame 158 (zoom: 19.8x): 0.060 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0158.ppm
# Frame 159 (zoom: 20.2x): 0.061 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0159.ppm
# Frame 160 (zoom: 20.6x): 0.062 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0160.ppm
# Frame 161 (zoom: 20.9x): 0.063 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0161.ppm
# Frame 162 (zoom: 21.3x): 0.063 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0162.ppm
# Frame 163 (zoom: 21.8x): 0.064 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0163.ppm
# Frame 164 (zoom: 22.2x): 0.065 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0164.ppm
# Frame 165 (zoom: 22.6x): 0.066 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0165.ppm
# Frame 166 (zoom: 23.0x): 0.067 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0166.ppm
# Frame 167 (zoom: 23.5x): 0.067 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0167.ppm
# Frame 168 (zoom: 23.9x): 0.068 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0168.ppm
# Frame 169 (zoom: 24.4x): 0.069 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0169.ppm
# Frame 170 (zoom: 24.9x): 0.069 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0170.ppm
# Frame 171 (zoom: 25.3x): 0.070 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0171.ppm
# Frame 172 (zoom: 25.8x): 0.070 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0172.ppm
# Frame 173 (zoom: 26.3x): 0.070 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0173.ppm
# Frame 174 (zoom: 26.8x): 0.070 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0174.ppm
# Frame 175 (zoom: 27.3x): 0.070 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0175.ppm
# Frame 176 (zoom: 27.9x): 0.071 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0176.ppm
# Frame 177 (zoom: 28.4x): 0.071 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0177.ppm
# Frame 178 (zoom: 28.9x): 0.071 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0178.ppm
# Frame 179 (zoom: 29.5x): 0.071 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0179.ppm
# Frame 180 (zoom: 30.1x): 0.071 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0180.ppm
# Frame 181 (zoom: 30.6x): 0.071 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0181.ppm
# Frame 182 (zoom: 31.2x): 0.071 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0182.ppm
# Frame 183 (zoom: 31.8x): 0.072 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0183.ppm
# Frame 184 (zoom: 32.4x): 0.072 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0184.ppm
# Frame 185 (zoom: 33.1x): 0.072 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0185.ppm
# Frame 186 (zoom: 33.7x): 0.072 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0186.ppm
# Frame 187 (zoom: 34.3x): 0.073 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0187.ppm
# Frame 188 (zoom: 35.0x): 0.073 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0188.ppm
# Frame 189 (zoom: 35.7x): 0.073 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0189.ppm
# Frame 190 (zoom: 36.4x): 0.073 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0190.ppm
# Frame 191 (zoom: 37.1x): 0.073 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0191.ppm
# Frame 192 (zoom: 37.8x): 0.073 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0192.ppm
# Frame 193 (zoom: 38.5x): 0.074 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0193.ppm
# Frame 194 (zoom: 39.2x): 0.074 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0194.ppm
# Frame 195 (zoom: 40.0x): 0.074 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0195.ppm
# Frame 196 (zoom: 40.8x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0196.ppm
# Frame 197 (zoom: 41.5x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0197.ppm
# Frame 198 (zoom: 42.3x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0198.ppm
# Frame 199 (zoom: 43.1x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0199.ppm
# Frame 200 (zoom: 44.0x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0200.ppm
# Frame 201 (zoom: 44.8x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0201.ppm
# Frame 202 (zoom: 45.7x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0202.ppm
# Frame 203 (zoom: 46.6x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0203.ppm
# Frame 204 (zoom: 47.4x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0204.ppm
# Frame 205 (zoom: 48.4x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0205.ppm
# Frame 206 (zoom: 49.3x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0206.ppm
# Frame 207 (zoom: 50.2x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0207.ppm
# Frame 208 (zoom: 51.2x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0208.ppm
# Frame 209 (zoom: 52.2x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0209.ppm
# Frame 210 (zoom: 53.2x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0210.ppm
# Frame 211 (zoom: 54.2x): 0.075 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0211.ppm
# Frame 212 (zoom: 55.2x): 0.076 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0212.ppm
# Frame 213 (zoom: 56.3x): 0.076 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0213.ppm
# Frame 214 (zoom: 57.4x): 0.077 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0214.ppm
# Frame 215 (zoom: 58.5x): 0.078 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0215.ppm
# Frame 216 (zoom: 59.6x): 0.079 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0216.ppm
# Frame 217 (zoom: 60.7x): 0.079 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0217.ppm
# Frame 218 (zoom: 61.9x): 0.080 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0218.ppm
# Frame 219 (zoom: 63.1x): 0.081 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0219.ppm
# Frame 220 (zoom: 64.3x): 0.081 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0220.ppm
# Frame 221 (zoom: 65.5x): 0.082 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0221.ppm
# Frame 222 (zoom: 66.8x): 0.083 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0222.ppm
# Frame 223 (zoom: 68.1x): 0.084 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0223.ppm
# Frame 224 (zoom: 69.4x): 0.084 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0224.ppm
# Frame 225 (zoom: 70.7x): 0.085 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0225.ppm
# Frame 226 (zoom: 72.1x): 0.086 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0226.ppm
# Frame 227 (zoom: 73.5x): 0.087 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0227.ppm
# Frame 228 (zoom: 74.9x): 0.087 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0228.ppm
# Frame 229 (zoom: 76.3x): 0.087 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0229.ppm
# Frame 230 (zoom: 77.8x): 0.087 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0230.ppm
# Frame 231 (zoom: 79.3x): 0.088 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0231.ppm
# Frame 232 (zoom: 80.8x): 0.088 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0232.ppm
# Frame 233 (zoom: 82.3x): 0.089 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0233.ppm
# Frame 234 (zoom: 83.9x): 0.089 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0234.ppm
# Frame 235 (zoom: 85.5x): 0.089 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0235.ppm
# Frame 236 (zoom: 87.2x): 0.090 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0236.ppm
# Frame 237 (zoom: 88.9x): 0.090 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0237.ppm
# Frame 238 (zoom: 90.6x): 0.090 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0238.ppm
# Frame 239 (zoom: 92.3x): 0.090 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0239.ppm
# Frame 240 (zoom: 94.1x): 0.090 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0240.ppm
# Frame 241 (zoom: 95.9x): 0.090 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0241.ppm
# Frame 242 (zoom: 97.7x): 0.091 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0242.ppm
# Frame 243 (zoom: 99.6x): 0.090 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0243.ppm
# Frame 244 (zoom: 101.5x): 0.090 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0244.ppm
# Frame 245 (zoom: 103.4x): 0.091 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0245.ppm
# Frame 246 (zoom: 105.4x): 0.091 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0246.ppm
# Frame 247 (zoom: 107.5x): 0.091 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0247.ppm
# Frame 248 (zoom: 109.5x): 0.091 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0248.ppm
# Frame 249 (zoom: 111.6x): 0.091 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0249.ppm
# Frame 250 (zoom: 113.8x): 0.091 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0250.ppm
# Frame 251 (zoom: 115.9x): 0.091 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0251.ppm
# Frame 252 (zoom: 118.2x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0252.ppm
# Frame 253 (zoom: 120.4x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0253.ppm
# Frame 254 (zoom: 122.8x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0254.ppm
# Frame 255 (zoom: 125.1x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0255.ppm
# Frame 256 (zoom: 127.5x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0256.ppm
# Frame 257 (zoom: 130.0x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0257.ppm
# Frame 258 (zoom: 132.5x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0258.ppm
# Frame 259 (zoom: 135.0x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0259.ppm
# Frame 260 (zoom: 137.6x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0260.ppm
# Frame 261 (zoom: 140.2x): 0.091 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0261.ppm
# Frame 262 (zoom: 142.9x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0262.ppm
# Frame 263 (zoom: 145.7x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0263.ppm
# Frame 264 (zoom: 148.5x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0264.ppm
# Frame 265 (zoom: 151.3x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0265.ppm
# Frame 266 (zoom: 154.2x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0266.ppm
# Frame 267 (zoom: 157.2x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0267.ppm
# Frame 268 (zoom: 160.2x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0268.ppm
# Frame 269 (zoom: 163.3x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0269.ppm
# Frame 270 (zoom: 166.4x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0270.ppm
# Frame 271 (zoom: 169.6x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0271.ppm
# Frame 272 (zoom: 172.8x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0272.ppm
# Frame 273 (zoom: 176.2x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0273.ppm
# Frame 274 (zoom: 179.5x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0274.ppm
# Frame 275 (zoom: 183.0x): 0.092 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0275.ppm
# Frame 276 (zoom: 186.5x): 0.091 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0276.ppm
# Frame 277 (zoom: 190.1x): 0.091 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0277.ppm
# Frame 278 (zoom: 193.7x): 0.091 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0278.ppm
# Frame 279 (zoom: 197.5x): 0.090 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0279.ppm
# Frame 280 (zoom: 201.2x): 0.090 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0280.ppm
# Frame 281 (zoom: 205.1x): 0.090 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0281.ppm
# Frame 282 (zoom: 209.0x): 0.089 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0282.ppm
# Frame 283 (zoom: 213.1x): 0.089 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0283.ppm
# Frame 284 (zoom: 217.1x): 0.088 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0284.ppm
# Frame 285 (zoom: 221.3x): 0.087 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0285.ppm
# Frame 286 (zoom: 225.6x): 0.087 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0286.ppm
# Frame 287 (zoom: 229.9x): 0.086 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0287.ppm
# Frame 288 (zoom: 234.3x): 0.086 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0288.ppm
# Frame 289 (zoom: 238.8x): 0.085 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0289.ppm
# Frame 290 (zoom: 243.4x): 0.085 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0290.ppm
# Frame 291 (zoom: 248.1x): 0.085 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0291.ppm
# Frame 292 (zoom: 252.8x): 0.084 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0292.ppm
# Frame 293 (zoom: 257.7x): 0.084 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0293.ppm
# Frame 294 (zoom: 262.6x): 0.084 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0294.ppm
# Frame 295 (zoom: 267.7x): 0.084 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0295.ppm
# Frame 296 (zoom: 272.8x): 0.084 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0296.ppm
# Frame 297 (zoom: 278.0x): 0.083 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0297.ppm
# Frame 298 (zoom: 283.4x): 0.083 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0298.ppm
# Frame 299 (zoom: 288.8x): 0.083 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0299.ppm
# Frame 300 (zoom: 294.4x): 0.082 seconds
# Saved: /content/drive/MyDrive/julia_set/julia_gpu_0300.ppm
#
# Average GPU time: 0.055 seconds
# GPU FPS: 18.14
#
# Saved: /content/drive/MyDrive/julia_set/gpu_values.csv
#
# ===========================================
# PERFORMANCE SUMMARY
# ===========================================
# Average CPU time: 2.211 seconds (0.45 FPS)
# Average GPU time: 0.055 seconds (18.14 FPS)
# Speedup:          40.11x faster on GPU
# ===========================================
#
#
# Output files saved to: /content/drive/MyDrive/julia_set/
# CPU: 30 frames (1 to 30)
# GPU: 300 frames (1 to 300)

# %%
# !grep -c "cpu_values.csv" julia_set.cu
# !grep -c "gpu_values.csv" julia_set.cu
# Out:
# 2
# 2

# %%
from google.colab import files

from PIL import Image, ImageDraw, ImageFont
import csv
import os

input_dir = '/content/drive/MyDrive/julia_set/'

print("WARNING: This will overwrite your original frames!")
print("Checking for CSV files...\n")

# Define both CPU and GPU configurations
configs = [
    {'csv': 'cpu_values.csv', 'prefix': 'julia_cpu_', 'name': 'CPU', 'output': 'cpu_julia_labeled.mp4'},
    {'csv': 'gpu_values.csv', 'prefix': 'julia_gpu_', 'name': 'GPU', 'output': 'gpu_julia_labeled.mp4'}
]

# Process each configuration if CSV exists
for config in configs:
    csv_file = f'{input_dir}{config["csv"]}'

    if not os.path.exists(csv_file):
        print(f"Skipping {config['name']}: {config['csv']} not found")
        continue

    print(f"\n{'='*50}")
    print(f"Processing {config['name']} frames from {config['csv']}")
    print(f"{'='*50}")

    # Read CSV file
    frame_data = {}
    fps = 30.0  # Default fallback

    with open(csv_file, 'r') as f:
        reader = csv.DictReader(f)
        for row in reader:
            if row['frame'] == 'fps':
                # Last line contains FPS
                fps = float(row['centerX'])
                print(f"Found {config['name']} FPS: {fps:.2f}")
            else:
                frame_num = int(row['frame'])
                frame_data[frame_num] = {
                    'centerX': float(row['centerX']),
                    'centerY': float(row['centerY']),
                    'zoom': float(row['zoom'])
                }

    num_frames = len(frame_data)
    print(f"Found {num_frames} frames in CSV")

    # Process each frame
    for frame_num, data in frame_data.items():
        img_path = f'{input_dir}{config["prefix"]}{frame_num:04d}.ppm'

        if not os.path.exists(img_path):
            print(f"Skipping frame {frame_num} - file not found")
            continue

        img = Image.open(img_path)
        draw = ImageDraw.Draw(img)

        # Try to load a nice font, fallback to default
        try:
            font = ImageFont.truetype("/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf", 24)
        except:
            font = ImageFont.load_default()

        # Create text using values from CSV
        text = f"Frame {frame_num} | Center ({data['centerX']:.15f}, {data['centerY']:.15f}) | Zoom {data['zoom']:.3f}x"

        # Get text size for background box
        bbox = draw.textbbox((0, 0), text, font=font)
        text_width = bbox[2] - bbox[0]
        text_height = bbox[3] - bbox[1]

        # Draw semi-transparent background box
        box_padding = 10
        box_coords = [
            10,
            img.height - text_height - box_padding - 10,
            text_width + box_padding + 20,
            img.height - 10
        ]
        draw.rectangle(box_coords, fill=(0, 0, 0, 180))

        # Draw text
        draw.text((15, img.height - text_height - 15), text, fill=(255, 255, 255), font=font)

        # Save back to original file
        img.save(img_path)

        if frame_num % 10 == 0:
            print(f"Processed frame {frame_num}")

    print(f"\n{config['name']} frames complete!")

    # Create video for this set using calculated FPS and actual frame count
    start_frame = min(frame_data.keys())
    end_frame = max(frame_data.keys())

    output_path = f'{input_dir}{config["output"]}'

    print(f"Creating {config['name']} video...")
    print(f"  Start frame: {start_frame}")
    print(f"  End frame: {end_frame}")
    print(f"  Total frames: {num_frames}")
    print(f"  FPS: {fps:.2f}")

    # !ffmpeg -y -framerate {fps} -start_number {start_frame} \
            -i {input_dir}{config["prefix"]}%04d.ppm \
            -frames:v {num_frames} -c:v libx264 -pix_fmt yuv420p \
            {output_path}

    print(f"{config['name']} video created: {output_path}\n")

print("\n" + "="*50)
print("All processing complete!")
print("="*50)

files.download('/content/drive/MyDrive/julia_set/cpu_julia_labeled.mp4')
files.download('/content/drive/MyDrive/julia_set/gpu_julia_labeled.mp4')
# Out:
# WARNING: This will overwrite your original frames!
# Checking for CSV files...
#
#
# ==================================================
# Processing CPU frames from cpu_values.csv
# ==================================================
# Found CPU FPS: 0.45
# Found 30 frames in CSV
# Processed frame 10
# Processed frame 20
# Processed frame 30
#
# CPU frames complete!
# Creating CPU video...
#   Start frame: 1
#   End frame: 30
#   Total frames: 30
#   FPS: 0.45
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '/content/drive/MyDrive/julia_set/julia_cpu_%04d.ppm':
#   Duration: 00:01:06.67, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: ppm, rgb24, 1920x1080, 0.45 fps, 0.45 tbr, 0.45 tbn, 0.45 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (ppm (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5a53aad362c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5a53aad362c0] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5a53aad362c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=1 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/drive/MyDrive/julia_set/cpu_julia_labeled.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1920x1080, q=2-31, 0.45 fps, 18432 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   30 fps=9.2 q=-1.0 Lsize=     697kB time=00:01:00.00 bitrate=  95.1kbits/s speed=18.3x
# video:695kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.165835%
# [libx264 @ 0x5a53aad362c0] frame I:1     Avg QP: 3.12  size: 42448
# [libx264 @ 0x5a53aad362c0] frame P:14    Avg QP: 8.91  size: 25996
# [libx264 @ 0x5a53aad362c0] frame B:15    Avg QP:10.51  size: 20338
# [libx264 @ 0x5a53aad362c0] consecutive B-frames: 16.7% 40.0% 30.0% 13.3%
# [libx264 @ 0x5a53aad362c0] mb I  I16..4: 83.8% 11.3%  4.9%
# [libx264 @ 0x5a53aad362c0] mb P  I16..4: 11.3%  2.2%  0.2%  P16..4:  7.4%  2.8%  2.2%  0.0%  0.0%    skip:73.9%
# [libx264 @ 0x5a53aad362c0] mb B  I16..4:  0.2%  0.1%  0.0%  B16..8:  9.7%  2.8%  1.2%  direct:10.1%  skip:75.8%  L0:51.5% L1:43.8% BI: 4.7%
# [libx264 @ 0x5a53aad362c0] 8x8 transform intra:14.8% inter:12.5%
# [libx264 @ 0x5a53aad362c0] coded y,uvDC,uvAC intra: 3.8% 33.0% 31.8% inter: 2.2% 13.8% 11.6%
# [libx264 @ 0x5a53aad362c0] i16 v,h,dc,p: 94%  3%  3%  0%
# [libx264 @ 0x5a53aad362c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20%  4% 64%  4%  2%  1%  3%  1%  2%
# [libx264 @ 0x5a53aad362c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 19% 42%  4%  4%  2%  3%  2%  2%
# [libx264 @ 0x5a53aad362c0] i8c dc,h,v,p: 80% 12%  5%  3%
# [libx264 @ 0x5a53aad362c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5a53aad362c0] ref P L0: 71.4%  1.8% 19.1%  7.7%
# [libx264 @ 0x5a53aad362c0] ref B L0: 75.5% 22.6%  1.9%
# [libx264 @ 0x5a53aad362c0] ref B L1: 98.5%  1.5%
# [libx264 @ 0x5a53aad362c0] kb/s:85.38
# CPU video created: /content/drive/MyDrive/julia_set/cpu_julia_labeled.mp4
#
#
# ==================================================
# Processing GPU frames from gpu_values.csv
# ==================================================
# Found GPU FPS: 18.14
# Found 300 frames in CSV
# Processed frame 10
# Processed frame 20
# Processed frame 30
# Processed frame 40
# Processed frame 50
# Processed frame 60
# Processed frame 70
# Processed frame 80
# Processed frame 90
# Processed frame 100
# Processed frame 110
# Processed frame 120
# Processed frame 130
# Processed frame 140
# Processed frame 150
# Processed frame 160
# Processed frame 170
# Processed frame 180
# Processed frame 190
# Processed frame 200
# Processed frame 210
# Processed frame 220
# Processed frame 230
# Processed frame 240
# Processed frame 250
# Processed frame 260
# Processed frame 270
# Processed frame 280
# Processed frame 290
# Processed frame 300
#
# GPU frames complete!
# Creating GPU video...
#   Start frame: 1
#   End frame: 300
#   Total frames: 300
#   FPS: 18.14
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '/content/drive/MyDrive/julia_set/julia_gpu_%04d.ppm':
#   Duration: 00:00:16.54, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: ppm, rgb24, 1920x1080, 18.14 fps, 18.14 tbr, 18.14 tbn, 18.14 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (ppm (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5ba026c4b440] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5ba026c4b440] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 0x5ba026c4b440] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=18 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/drive/MyDrive/julia_set/gpu_julia_labeled.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1920x1080, q=2-31, 18.14 fps, 14512 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  300 fps=2.7 q=-1.0 Lsize=  118888kB time=00:00:16.37 bitrate=59484.7kbits/s speed=0.147x
# video:118884kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.003036%
# [libx264 @ 0x5ba026c4b440] frame I:2     Avg QP:17.14  size:184751
# [libx264 @ 0x5ba026c4b440] frame P:235   Avg QP:26.35  size:508494
# [libx264 @ 0x5ba026c4b440] frame B:63    Avg QP:19.42  size: 29697
# [libx264 @ 0x5ba026c4b440] consecutive B-frames: 68.7%  8.7%  4.0% 18.7%
# [libx264 @ 0x5ba026c4b440] mb I  I16..4: 31.7% 47.2% 21.1%
# [libx264 @ 0x5ba026c4b440] mb P  I16..4: 18.9% 18.0% 22.2%  P16..4: 11.0%  5.2%  2.6%  0.0%  0.0%    skip:22.2%
# [libx264 @ 0x5ba026c4b440] mb B  I16..4:  1.1%  0.9%  1.0%  B16..8: 10.3%  3.0%  1.2%  direct:16.8%  skip:65.6%  L0:45.6% L1:42.4% BI:12.0%
# [libx264 @ 0x5ba026c4b440] 8x8 transform intra:30.6% inter:9.3%
# [libx264 @ 0x5ba026c4b440] coded y,uvDC,uvAC intra: 76.7% 85.4% 81.2% inter: 12.7% 31.5% 20.5%
# [libx264 @ 0x5ba026c4b440] i16 v,h,dc,p:  9%  4% 72% 16%
# [libx264 @ 0x5ba026c4b440] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15%  8% 56%  4%  3%  3%  3%  3%  4%
# [libx264 @ 0x5ba026c4b440] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11%  9% 30% 10%  8%  8%  8%  7%  8%
# [libx264 @ 0x5ba026c4b440] i8c dc,h,v,p: 71%  7%  6% 15%
# [libx264 @ 0x5ba026c4b440] Weighted P-Frames: Y:0.4% UV:0.0%
# [libx264 @ 0x5ba026c4b440] ref P L0: 49.0%  6.4% 28.7% 15.9%  0.0%
# [libx264 @ 0x5ba026c4b440] ref B L0: 88.2% 10.4%  1.5%
# [libx264 @ 0x5ba026c4b440] ref B L1: 98.4%  1.6%
# [libx264 @ 0x5ba026c4b440] kb/s:58888.03
# GPU video created: /content/drive/MyDrive/julia_set/gpu_julia_labeled.mp4
#
#
# ==================================================
# All processing complete!
# ==================================================
